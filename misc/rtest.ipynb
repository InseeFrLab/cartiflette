# %%
import dev

# %%
niv_ad = dev.get_administrative_level_available_ign()
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2022
# Available administrative levels are :
#   - DEPARTEMENT
#   - CHFLIEU_ARRONDISSEMENT_MUNICIPAL
#   - CHFLIEU_COMMUNE_ASSOCIEE_OU_DELEGUEE
#   - REGION
#   - COLLECTIVITE_TERRITORIALE
#   - ARRONDISSEMENT
#   - COMMUNE_ASSOCIEE_OU_DELEGUEE
#   - CHFLIEU_COMMUNE
#   - EPCI
#   - ARRONDISSEMENT_MUNICIPAL
#   - CANTON
#   - COMMUNE

# %%
niv_ad = dev.get_administrative_level_available_ign(year=2021)

# %%
niv_ad = dev.get_administrative_level_available_ign(year=2020)

# %%
niv_ad = dev.get_administrative_level_available_ign(year=2019)

# %%
niv_ad = dev.get_administrative_level_available_ign(year=2018)
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2018
# Available administrative levels are :
#   - EPCI_CARTO
#   - DEPARTEMENT
#   - REGION
#   - COMMUNE_CARTO
#   - ARRONDISSEMENT_DEPARTEMENTAL
#   - REGION_CARTO
#   - EPCI
#   - ARRONDISSEMENT_DEPARTEMENTAL_CARTO
#   - CHEF_LIEU
#   - DEPARTEMENT_CARTO
#   - COMMUNE

# %%
niv_ad = dev.get_administrative_level_available_ign(year=2017)
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2017
# Available administrative levels are :
#   - EPCI_CARTO
#   - DEPARTEMENT
#   - REGION
#   - COMMUNE_CARTO
#   - ARRONDISSEMENT_DEPARTEMENTAL
#   - REGION_CARTO
#   - EPCI
#   - ARRONDISSEMENT_DEPARTEMENTAL_CARTO
#   - CHEF_LIEU
#   - DEPARTEMENT_CARTO
#   - COMMUNE

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "martinique").plot()

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "martinique", year=2021).plot()

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "martinique", year = 2020).plot()

# %%
dev.get_shapefile_ign(level = "REGION", field = "martinique", year = 2019).plot()

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "martinique", year = 2018).plot()
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2018
# <AxesSubplot:>

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "martinique", year = 2017).plot()
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2017
# <AxesSubplot:>

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "martinique", year = 2018).plot()
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2018
# <AxesSubplot:>

# %%
dev.get_shapefile_ign(level = "COMMUNE", field = "reunion").plot()

# %%
dev.get_shapefile_ign(level = "REGION", field = "metropole").plot()

# %%
dev.get_shapefile_ign(level = "REGION", field = "metropole", year=2021).plot()
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2021
# <AxesSubplot:>

# %%
df = dev.get_shapefile_ign(level = "REGION", field = "metropole", year=2017)
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2017

# %%
import urllib 
import ftplib

ftp = FTP('ftp://Admin_Express_ext:Dahnoh0eigheeFok@ftp3.ign.fr/ADMIN-EXPRESS-COG_3-0__SHP__FRA_L93_2021-05-19.7z')
ftp_server.dir()

# %%
df = dev.get_shapefile_ign(level = "COMMUNE", field = "metropole", year=2017)
# Out:
# Data have been previously downloaded and are still available in /tmp/EXPRESS-COG-2017

# %%
df.head(2)
# Out:
#                          ID           STATUT INSEE_COM                NOM_COM  \
# 0  BDCSURCO0000000009587541   Commune simple     54166  Dommartin-la-Chaussée
# 1  BDCSURCO0000002000697956  Sous-préfecture     54099           Val de Briey
#
#   INSEE_ARR             NOM_DEP INSEE_DEP    NOM_REG INSEE_REG  CODE_EPCI  \
# 0         4  MEURTHE-ET-MOSELLE        54  GRAND EST        44  200070738
# 1         1  MEURTHE-ET-MOSELLE        54  GRAND EST        44  200070845
#
#                NOM_COM_M                                           geometry
# 0  DOMMARTIN-LA-CHAUSSEE  POLYGON ((909246.000 6883637.000, 909330.000 6...
# 1           VAL DE BRIEY  POLYGON ((920506.000 6907964.000, 920496.000 6...

# %%
import dbf
table = dbf.Table('/tmp/EXPRESS-COG-2017/ADMIN-EXPRESS-COG_1-0__SHP__FRA_2017-06-19/ADMIN-EXPRESS-COG/1_DONNEES_LIVRAISON_2017-06-19/ADE-COG_1-0_SHP_UTM22RGFG95_D973/EPCI_CARTO.dbf')
table.structure()
# Out:
# FieldnameList(['ID C(24)', 'CODE_EPCI C(9)', 'NOM_EPCI C(230)', 'TYPE_EPCI C(9)'])

# %%
os.listdir('/tmp/EXPRESS-COG-2017/ADMIN-EXPRESS-COG_1-0__SHP__FRA_2017-06-19/ADMIN-EXPRESS-COG/1_DONNEES_LIVRAISON_2017-06-19/ADE-COG_1-0_SHP_UTM22RGFG95_D973')
# Out:
# ['REGION.dbf',
#  'EPCI_CARTO.shp',
#  'DEPARTEMENT.shp',
#  'DEPARTEMENT.prj',
#  'EPCI_CARTO.prj',
#  'REGION_CARTO.shx',
#  'ARRONDISSEMENT_DEPARTEMENTAL_CARTO.dbf',
#  'CHEF_LIEU.cpg',
#  'ARRONDISSEMENT_DEPARTEMENTAL.shx',
#  'REGION.shp',
#  'REGION.cpg',
#  'CHEF_LIEU.prj',
#  'COMMUNE_CARTO.shp',
#  'ARRONDISSEMENT_DEPARTEMENTAL_CARTO.prj',
#  'COMMUNE.shx',
#  'ARRONDISSEMENT_DEPARTEMENTAL.prj',
#  'ARRONDISSEMENT_DEPARTEMENTAL.dbf',
#  'EPCI.shx',
#  'DEPARTEMENT_CARTO.prj',
#  'COMMUNE.cpg',
#  'COMMUNE_CARTO.cpg',
#  'COMMUNE_CARTO.shx',
#  'ARRONDISSEMENT_DEPARTEMENTAL.shp',
#  'REGION_CARTO.prj',
#  'EPCI_CARTO.dbf',
#  'COMMUNE.dbf',
#  'REGION_CARTO.cpg',
#  'DEPARTEMENT_CARTO.cpg',
#  'DEPARTEMENT_CARTO.shx',
#  'EPCI.cpg',
#  'REGION_CARTO.shp',
#  'DEPARTEMENT.cpg',
#  'DEPARTEMENT_CARTO.dbf',
#  'ARRONDISSEMENT_DEPARTEMENTAL_CARTO.cpg',
#  'CHEF_LIEU.shx',
#  'EPCI.shp',
#  'ARRONDISSEMENT_DEPARTEMENTAL.cpg',
#  'COMMUNE.prj',
#  'CHEF_LIEU.dbf',
#  'EPCI.prj',
#  'DEPARTEMENT.shx',
#  'REGION.shx',
#  'EPCI.dbf',
#  'ARRONDISSEMENT_DEPARTEMENTAL_CARTO.shp',
#  'REGION.prj',
#  'EPCI_CARTO.cpg',
#  'DEPARTEMENT.dbf',
#  'ARRONDISSEMENT_DEPARTEMENTAL_CARTO.shx',
#  'EPCI_CARTO.shx',
#  'CHEF_LIEU.shp',
#  'REGION_CARTO.dbf',
#  'DEPARTEMENT_CARTO.shp',
#  'COMMUNE_CARTO.dbf',
#  'COMMUNE_CARTO.prj',
#  'COMMUNE.shp']
